# %%
from bs4 import BeautifulSoup
import googlemaps
from datetime import datetime
from pprint import pprint
import csv
import unidecode
import re

# %%
import pandas as pd

# %%
headers =[]
totList = []

with open("/Users/defcon/Downloads/SoiltestingLab.xls","r") as f:
    soup = BeautifulSoup(f.read(),"html5lib")
    for row in soup.findAll("tr") :
        for td in row.findAll("th") :
            headers.append(unidecode.unidecode((td.string)))
        i=0
        tempDict = {}
        for td in row.findAll("td") :
            tempDict[headers[i]] =unidecode.unidecode((td.string))
            
            i+=1

        totList.append(tempDict)

# %%
gMapAPIKey = "AIzaSyDos79xVwv-Zz3NV4YaaPkN1eQ4XEgtNAo"

# %%
gmaps = googlemaps.Client(key=gMapAPIKey)

# %%
for tot in totList :
    tot["address"] = re.sub( '\s+', ' ', tot["blockNameEng"] + " " +tot["SubDistName"]+" " +tot["districtnm"] + " " + tot["statenm"] ).strip()

# %%
locNotFound = list()

# %%
# pprint(gmaps.geocode("IIT Kharagpur"))

for tot in totList :
    loc = gmaps.geocode(tot["address"])
    print (tot["address"])
    pprint(loc)
    try :
            tot["lat"] = loc[0]["geometry"]["location"]["lat"]
            tot["long"] = loc[0]["geometry"]["location"]["lng"]
    except : 
        locNotFound.append(tot)
# Out:
# Port Blair SOUTH ANDAMAN A AND N ISLANDS
# [{'address_components': [{'long_name': 'Port Blair',
#                           'short_name': 'Port Blair',
#                           'types': ['locality', 'political']},
#                          {'long_name': 'Andaman and Nicobar Islands',
#                           'short_name': 'AN',
#                           'types': ['administrative_area_level_1',
#                                     'political']},
#                          {'long_name': 'India',
#                           'short_name': 'IN',
#                           'types': ['country', 'political']},
#                          {'long_name': '744106',
#                           'short_name': '744106',
#                           'types': ['postal_code']}],
#   'formatted_address': 'South Point, Shadipur, Port Blair, Andaman and Nicobar '
#                        'Islands, Port Blair, Andaman and Nicobar Islands '
#                        '744106, India',
# ...

# %%
print ((locNotFound))
# Out:
# [{'SRNo': '12', 'Sno': '1706', 'StateCD': '01', 'DistrictCD': '0112', 'BlockCode': '4845', 'SubDistrictCD': '05743', 'VillageCode': '9146', 'LabType': 'Govt', 'LabName': 'AMC, STL, Proddutur', 'districtnm': 'CUDDEPAH', 'blockNameEng': 'PRODDATUR                                         ', 'Email': 'adastlysr@gmail.com', 'Mobile': '9160787856', 'MNTF': 'Yes', 'BTF': 'No', 'STF': 'Yes', 'Prsn_Soil': '1', 'Prsn_Technical': '1', 'Prsn_Supporting': '1', 'An_Routine': '2000', 'An_Full': '0', 'Sa_Routine': '1505', 'Sa_Full': '0', 'Charges_Full_Actual': '130', 'Charges_Full_Charged': '30', 'Charges_Routine_Actual': '75', 'Charges_Routine_Charged': '10', 'Govt_Funding': 'State Government Scheme', 'Static_Mobile': 'Static', 'Status': 'Complete', 'Town_Village_Name': 'Attur ', 'SubDistName': 'Attur', 'statenm': 'ANDHRA PRADESH', 'address': 'PRODDATUR Attur CUDDEPAH ANDHRA PRADESH'}, {'SRNo': '13', 'Sno': '1722', 'StateCD': '01', 'DistrictCD': '0112', 'BlockCode': '4823', 'SubDistrictCD': '05743'
# ...

# %%
print(headers)
# Out:
# ['SRNo', 'Sno', 'StateCD', 'DistrictCD', 'BlockCode', 'SubDistrictCD', 'VillageCode', 'LabType', 'LabName', 'districtnm', 'blockNameEng', 'Email', 'Mobile', 'MNTF', 'BTF', 'STF', 'Prsn_Soil', 'Prsn_Technical', 'Prsn_Supporting', 'An_Routine', 'An_Full', 'Sa_Routine', 'Sa_Full', 'Charges_Full_Actual', 'Charges_Full_Charged', 'Charges_Routine_Actual', 'Charges_Routine_Charged', 'Govt_Funding', 'Static_Mobile', 'Status', 'Town_Village_Name', 'SubDistName', 'statenm']

# %%
import csv

keys = totList[0].keys()
with open('soilLabs.csv', 'w') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(totList)

# %%
re.sub( '\s+', ' ', "sdkvbiwvw vwv w ev w v .     w vwe v ewv" ).strip()
# Out:
# 'sdkvbiwvw vwv w ev w v . w vwe v ewv'

# %%
totList.remove({})
